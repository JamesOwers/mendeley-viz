# %%
import sqlite3
import os
import pandas as pd
import platform
import sys

# %%
platform.platform(), platform.system(), platform.release(), sys.platform, os.uname()
# Out:
# ('Linux-3.16.0-38-generic-x86_64-with-debian-jessie-sid',
#  'Linux',
#  '3.16.0-38-generic',
#  'linux2',
#  ('Linux',
#   'james-HP-EliteDesk-800-G1-SFF',
#   '3.16.0-38-generic',
#   '#52~14.04.1-Ubuntu SMP Fri May 8 09:43:57 UTC 2015',
#   'x86_64'))

# %%
HOME = os.environ['HOME']
email = 'james.f.owers+mendeley@gmail.com'
# http://support.mendeley.com/customer/en/portal/articles/227951-how-do-i-locate-mendeley-desktop-database-files-on-my-computer-
loc = dict(
    Darwin='Library/Application Support/Mendeley Desktop',
    Linux='.local/share/data/Mendeley Ltd./Mendeley Desktop'
) 
db_loc = '{}{}{}@www.mendeley.com.sqlite'.format(loc[platform.system()], os.sep, email).split('/')
db_path = '{}{}{}'.format(HOME, os.sep, os.sep.join(db_loc))
conn = sqlite3.connect(db_path)

# %%
db_path
# Out:
# '/home/james/.local/share/data/Mendeley Ltd./Mendeley Desktop/james.f.owers+mendeley@gmail.com@www.mendeley.com.sqlite'

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [(u'Documents',), (u'sqlite_sequence',), (u'DocumentContributors',), (u'DocumentFiles',), (u'Files',), (u'DocumentFolders',), (u'DocumentKeywords',), (u'DocumentReferences',), (u'DocumentTags',), (u'DocumentUrls',), (u'Folders',), (u'FileHighlights',), (u'FileHighlightRects',), (u'FileNotes',), (u'DocumentNotes',), (u'ZoteroLastSync',), (u'DocumentZotero',), (u'Stats',), (u'Settings',), (u'EventLog',), (u'EventAttributes',), (u'FileViewStates',), (u'NotDuplicates',), (u'HtmlLocalStorage',), (u'ImportHistory',), (u'LastReadStates',), (u'Profiles',), (u'RemoteDocuments',), (u'Groups',), (u'RemoteFolders',), (u'DocumentDetailsBase',), (u'DocumentFields',), (u'DocumentVersion',), (u'RemoteFileHighlights',), (u'RemoteFileNotes',), (u'RemoteDocumentNotes',), (u'DocumentFoldersBase',), (u'Resources',), (u'CanonicalDocuments',), (u'DocumentCanonicalIds',), (u'SyncTokens',), (u'SchemaVersion',), (u'RunsSinceLastCleanup',), (u'DataCleaner',)]

# %%
# !!ls
# Out:
# ['csv', 'LICENSE', 'Read and search database.ipynb', 'README.md']

# %%
a = _

# %%
# !mkdir -p csv

# %%
# !ls
# Out:
# csv  LICENSE  Read and search database.ipynb  README.md

# %%
out_loc = 'csv'

# %%
db = conn
cursor = db.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table_name in tables:
    table_name = table_name[0]
    table = pd.read_sql_query("SELECT * from %s" % table_name, db)
    table.to_csv('{}{}{}.csv'.format(out_loc, os.sep, table_name), 
                 index_label='index', 
                 encoding = 'utf-8')

# %%
table_name = 'Documents'
documents = pd.read_sql_query("SELECT * from {}".format(table_name), db)
documents[['id', 'type', 'note', 'title', 'year']]
# Out:
#       id                   type  note  \
# 0      1         JournalArticle  None
# 1      2                   Book  None
# 2      3         JournalArticle  None
# 3      4         JournalArticle  None
# 4      5         JournalArticle  None
# 5      6         JournalArticle  None
# 6      7         JournalArticle  None
# 7      8         JournalArticle  None
# 8      9                   Book  None
# 9     10         JournalArticle  None
# 10    11         JournalArticle  None
# 11    12                   Book  None
# 12    13         JournalArticle  None
# 13    14         JournalArticle  None
# 14    15         JournalArticle  None
# 15    16         JournalArticle  None
# 16    17         JournalArticle  None
# 17    18         JournalArticle  None
# 18    19         JournalArticle  None
# 19    20         JournalArticle  None
# 20    21         JournalArticle  None
# 21    22         JournalArticle  None
# 22    23         JournalArticle  None
# 23    24         JournalArticle  None
# 24    25         JournalArticle  None
# 25    26         JournalArticle  None
# 26    27                   Book  None
# 27    28         JournalArticle  None
# 28    29         JournalArticle  None
# 29    30         JournalArticle  None
# ..   ...                    ...   ...
# 536  579         JournalArticle  None
# 537  580         JournalArticle  None
# 538  581         JournalArticle  None
# 539  582                Generic  None
# 540  583                Generic  None
# 541  584                Generic  None
# 542  585                Generic  None
# 543  586         JournalArticle  None
# 544  587         JournalArticle  None
# 545  588         JournalArticle  None
# 546  589         JournalArticle  None
# 547  590                   Book  None
# 548  591                Generic  None
# 549  592         JournalArticle  None
# 550  593         JournalArticle  None
# 551  594         JournalArticle  None
# 552  595                Generic  None
# 553  596                   Book  None
# 554  597         JournalArticle  None
# 555  598                Generic  None
# 556  599         JournalArticle  None
# 557  600         JournalArticle  None
# 558  601         JournalArticle  None
# 559  602         JournalArticle  None
# 560  603  ConferenceProceedings  None
# 561  604         JournalArticle  None
# 562  605                   Book  None
# 563  606         JournalArticle  None
# 564  607         JournalArticle  None
# 565  608                   Book  None
#
#                                                  title    year
# 0    Optimal personalized treatment rules for marke...     NaN
# 1                  Kernel methods for pattern analysis  2004.0
# 2    Three conditions under which experiments and o...  2008.0
# 3                                        Random Forest  2012.0
# 4    Machine learning techniques to examine large p...  2009.0
# 5                                         Node harvest  2010.0
# 6    Representation Learning : A Review and New Per...  2012.0
# 7                                               Spss u     NaN
# 8             Introduction to Semi-Supervised Learning  2009.0
# 9                             Improving Random Forests  2004.0
# 10   Understanding Heterogeneity in Response to Ant...  2013.0
# 11            Pattern recognition and machine learning  2006.0
# 12   An AUC-based permutation variable importance m...  2013.0
# 13   Decision Forests: A Unified Framework for Clas...  2011.0
# 14   Matching as Nonparametric Preprocessing for Re...  2006.0
# 15   University of California , Berkeley Super Lear...  2010.0
# 16   Linear Partial Differential Equations and Four...  2010.0
# 17   On Estimating Model Accuracy with Repeated Cro...  2012.0
# 18   Concept of Sensitivity & Co . applied to the G...  2013.0
# 19                                          Party on !     NaN
# 20   Unbiased Recursive Partitioning: A Conditional...  2006.0
# 21   STORMS PREDICTION : LOGISTIC REGRESSION VS RAN...  2005.0
# 22   Fast and accurate short read alignment with Bu...  2009.0
# 23   Decision Forests for Classification , Regressi...  2011.0
# 24   Preventing Over-Fitting during Model Selection...  2007.0
# 25   % PROC _ R : A SAS Macro that Enables Native R...  2012.0
# 26                                   D EEP L EARNING :  2014.0
# 27   Manual--Setting Up, Using, And Understanding R...     NaN
# 28   The Sanger FASTQ file format for sequences wit...  2009.0
# 29   An Improved Random Forests Approach with Appli...  1996.0
# ..                                                 ...     ...
# 536  Deep Neural Networks for Acoustic Modeling in ...  2012.0
# 537              Development of the RWC music database  2004.0
# 538                     University of California Press  2015.0
# 539  Observation of the sporadic background in Nov....  1978.0
# 540                  Instrument Library (MUMS) Revised  2008.0
# 541  ``OLPC Free Sound Samples'' [Online]. Availabl...     NaN
# 542  ``Freesound Project'' [Online]. Available: htt...     NaN
# 543                                   Convention Paper  2010.0
# 544  good-sounds.org : a Framework To Explore Goodn...  2016.0
# 545             Communication in the Presence of Noise  1949.0
# 546  Dropout as a Bayesian Approximation : Represen...  2015.0
# 547  Learning Internal Representations by Error Pro...  1986.0
# 548  "Neural Networks and Deep Learning", Determina...  2015.0
# 549  An Automatic Method for Finding the Greatest o...  1960.0
# 550         Adam: A Method for Stochastic Optimization  2015.0
# 551  Improving neural networks by preventing co-ada...  2012.0
# 552                Classification and Regression Trees  1999.0
# 553  Decision forests for computer vision and medic...  2013.0
# 554                 Learning Deep Architectures for AI  2009.0
# 555      Deep Learning in neural networks: An overview  2015.0
# 556  Moving Beyond Feature Design: Deep Architectur...  2012.0
# 557  A general flexible framework for the handling ...  2012.0
# 558  Music in Our Ears: The Biological Bases of Mus...  2012.0
# 559          WaveNet: A Generative Model for Raw Audio  2016.0
# 560  Improved music feature learning with deep neur...  2014.0
# 561  an Efficient Temporally-Constrained Probabilis...  2015.0
# 562  Bayesian spectrum analysis and parameter estim...  1988.0
# 563               Bayesian spectrum and chirp analysis  1987.0
# 564                        The Physical Basis of Music  1886.0
# 565           Probability Theory: The Logic of Science  2014.0
#
# [566 rows x 5 columns]

# %%
documents.loc[documents['note'].notnull(), ['id', 'type', 'note', 'title', 'year']]
# Out:
# Empty DataFrame
# Columns: [id, type, note, title, year]
# Index: []

# %%
pd.set_option('display.max_columns', 100)
documents.loc[documents['title']=='An efficient algorithm for the calculation of a constant Q transform',:]
# Out:
#       id                                    uuid confirmed deduplicated  \
# 458  501  {d6c1f910-852b-4547-b369-6443054f6dd7}      true        false
# 463  506  {fb00c5e7-ff64-4c82-a617-f0fc9fd9f064}      true         true
# 473  516  {ab04dd67-2e18-4c23-97b0-a16b5a7b74d4}      true        false
#
#     deletionPending favourite   read            type  \
# 458           false      None   None  JournalArticle
# 463            true     false  false  JournalArticle
# 473           false     false  false  JournalArticle
#
#                                               abstract          added  \
# 458  An efficient method of transforming a discrete...  1461138456000
# 463  An efficient method of transforming a discrete...  1461138456000
# 473  An efficient method of transforming a discrete...  1464816003000
#
#           modified                 importer  note         privacy  \
# 458  1465993465391              PdfImporter  None  NormalDocument
# 463  1460932480177  MergedDocumentsImporter  None  NormalDocument
# 473  1490284459507  MergedDocumentsImporter  None  NormalDocument
#
#                                                  title advisor articleColumn  \
# 458  An efficient algorithm for the calculation of ...    None          None
# 463  An efficient algorithm for the calculation of ...    None          None
# 473  An efficient algorithm for the calculation of ...    None          None
#
#     applicationNumber arxivId chapter citationKey  city  code codeNumber  \
# 458              None    None    None   Brown1992  None  None       None
# 463              None    None    None   Brown1992  None  None       None
# 473              None    None    None   Brown1992  None  None       None
#
#     codeSection codeVolume committee counsel country dateAccessed  day  \
# 458        None       None      None    None    None         None  NaN
# 463        None       None      None    None    None         None  NaN
# 473        None       None      None    None    None         None  NaN
#
#     department               doi edition genre hideFromMendeleyWebIndex  \
# 458       None  10.1121/1.404385    None  None                    false
# 463       None  10.1121/1.404385    None  None                    false
# 473       None  10.1121/1.404385    None  None                    false
#
#     institution internationalAuthor internationalNumber internationalTitle  \
# 458        None                None                None               None
# 463        None                None                None               None
# 473        None                None                None               None
#
#     internationalUserType        isbn      issn issue language lastUpdate  \
# 458                  None  0104251050  00014966     5     None       None
# 463                  None  0104251050  00014966     5     None       None
# 473                  None  0104251050  00014966     5     None       None
#
#     legalStatus length medium  month originalPublication owner pages  pmid  \
# 458        None   None   None    NaN                None  None  2698  None
# 463        None   None   None    NaN                None  None  2698  None
# 473        None   None   None    NaN                None  None  2698  None
#
#                                           publication publicLawNumber  \
# 458  The Journal of the Acoustical Society of America            None
# 463  The Journal of the Acoustical Society of America            None
# 473  The Journal of the Acoustical Society of America            None
#
#     publisher reprintEdition reviewedArticle revisionNumber sections  \
# 458      None           None            None           None     None
# 463      None           None            None           None     None
# 473      None           None            None           None     None
#
#     seriesEditor series seriesNumber session shortTitle sourceType userType  \
# 458         None   None         None    None       None       None     None
# 463         None   None         None    None       None       None     None
# 473         None   None         None    None       None       None     None
#
#     volume    year
# 458     92  1992.0
# 463     92  1992.0
# 473     92  1992.0

# %%
pd.reset_option('display.max_columns')

# %%
documents.columns
# Out:
# Index([u'id', u'uuid', u'confirmed', u'deduplicated', u'deletionPending',
#        u'favourite', u'read', u'type', u'abstract', u'added', u'modified',
#        u'importer', u'note', u'privacy', u'title', u'advisor',
#        u'articleColumn', u'applicationNumber', u'arxivId', u'chapter',
#        u'citationKey', u'city', u'code', u'codeNumber', u'codeSection',
#        u'codeVolume', u'committee', u'counsel', u'country', u'dateAccessed',
#        u'day', u'department', u'doi', u'edition', u'genre',
#        u'hideFromMendeleyWebIndex', u'institution', u'internationalAuthor',
#        u'internationalNumber', u'internationalTitle', u'internationalUserType',
#        u'isbn', u'issn', u'issue', u'language', u'lastUpdate', u'legalStatus',
#        u'length', u'medium', u'month', u'originalPublication', u'owner',
#        u'pages', u'pmid', u'publication', u'publicLawNumber', u'publisher',
#        u'reprintEdition', u'reviewedArticle', u'revisionNumber', u'sections',
#        u'seriesEditor', u'series', u'seriesNumber', u'session', u'shortTitle',
#        u'sourceType', u'userType', u'volume', u'year'],
#       dtype='object')

# %%
table_name = 'DocumentContributors'
contribs = pd.read_sql_query("SELECT * from {}".format(table_name), db)
contribs
# Out:
#         id  documentId    contribution            firstNames      lastName
# 0        1           1  DocumentAuthor                   Leo       Guelman
# 1        2           2  DocumentAuthor                  John  Shawe-taylor
# 2        3           3  DocumentAuthor              Thomas D          Cook
# 3        4           3  DocumentAuthor             William R       Shadish
# 4        5           3  DocumentAuthor              Vivian C          Wong
# 5        6           4  DocumentAuthor  Applied Multivariate    Statistics
# 6        7           5  DocumentAuthor                 Geert     Meyfroidt
# 7        8           5  DocumentAuthor                Fabian         Güiza
# 8        9           5  DocumentAuthor                   Jan         Ramon
# 9       10           5  DocumentAuthor               Maurice    Bruynooghe
# 10      11           6  DocumentAuthor               Nicolai   Meinshausen
# 11      12           7  DocumentAuthor                Yoshua        Bengio
# 12      13           7  DocumentAuthor                 Aaron     Courville
# 13      14           7  DocumentAuthor                Pascal       Vincent
# 14      15           8  DocumentAuthor                   Bob      Muenchen
# 15      16           9  DocumentAuthor               Xiaojin           Zhu
# 16      17           9  DocumentAuthor             Andrew B.      Goldberg
# 17      18          10  DocumentAuthor         Marko Robnik-       Sikonja
# 18      19          11  DocumentAuthor               Anthony         Zagar
# 19      20          11  DocumentAuthor                   Lei          Chen
# 20      21          11  DocumentAuthor            Kristina S          Boye
# 21      22          11  DocumentAuthor                     R            Ph
# 22      23          11  DocumentAuthor                     D            Ph
# 23      24          11  DocumentAuthor             Honghua H         Jiang
# 24      25          11  DocumentAuthor                Ilya A     Lipkovich
# 25      26          12  DocumentAuthor                    CM        Bishop
# 26      27          13  DocumentAuthor                 Silke       Janitza
# 27      28          13  DocumentAuthor               Carolin        Strobl
# 28      29          13  DocumentAuthor            Anne-Laure    Boulesteix
# 29      30          14  DocumentAuthor               Antonio     Criminisi
# ...    ...         ...             ...                   ...           ...
# 2037  2233         596  DocumentAuthor                 Jamie       Shotton
# 2038  2234         597  DocumentAuthor                Yoshua        Bengio
# 2039  2235         598  DocumentAuthor                Jürgen   Schmidhuber
# 2040  2236         599  DocumentAuthor                Eric J      Humphrey
# 2041  2237         599  DocumentAuthor            Juan Pablo         Bello
# 2042  2238         599  DocumentAuthor                  Yann         LeCun
# 2043  2239         600  DocumentAuthor                Alexey        Ozerov
# 2044  2240         600  DocumentAuthor              Emmanuel       Vincent
# 2045  2241         600  DocumentAuthor            Fr??d??ric        Bimbot
# 2046  2242         601  DocumentAuthor               Kailash         Patil
# 2047  2243         601  DocumentAuthor                Daniel   Pressnitzer
# 2048  2244         601  DocumentAuthor                Shihab        Shamma
# 2049  2245         601  DocumentAuthor                Mounya      Elhilali
# 2050  2246         602  DocumentAuthor         Aaron van den          Oord
# 2051  2247         602  DocumentAuthor                Sander      Dieleman
# 2052  2248         602  DocumentAuthor                 Heiga           Zen
# 2053  2249         602  DocumentAuthor                 Karen      Simonyan
# 2054  2250         602  DocumentAuthor                 Oriol       Vinyals
# 2055  2251         602  DocumentAuthor                  Alex        Graves
# 2056  2252         602  DocumentAuthor                   Nal  Kalchbrenner
# 2057  2253         602  DocumentAuthor                Andrew        Senior
# 2058  2254         602  DocumentAuthor                 Koray   Kavukcuoglu
# 2059  2255         603  DocumentAuthor             Siddharth        Sigtia
# 2060  2256         603  DocumentAuthor                 Simon         Dixon
# 2061  2257         604  DocumentAuthor             Emmanouil       Benetos
# 2062  2258         604  DocumentAuthor               Tillman         Weyde
# 2063  2259         605  DocumentAuthor               G Larry    Bretthorst
# 2064  2260         606  DocumentAuthor                   E T        Jaynes
# 2065  2261         607  DocumentAuthor                     J             J
# 2066  2262         608  DocumentAuthor                  E.T.         Janes
#
# [2067 rows x 5 columns]

# %%
table_name = 'DocumentNotes'
notes = pd.read_sql_query("SELECT * from {}".format(table_name), db)
notes
# Out:
#     id                                  uuid  \
# 0   20  004a86a9-467d-31e2-898d-f29b25f455c7
# 1   21  c6fb31ed-e14c-3c8f-b8c7-3a0422086842
# 2   22  3757f864-52ea-3072-9dee-6bfe137b0b5c
# 3   23  0cad26fd-6225-3046-94bf-c099ddcd5055
# 4   24  4f73b40e-5971-3fa1-98d0-ffb9ba71fe95
# 5   25  272a0b35-1c17-3748-adc2-671662d4bc2f
# 6   26  68482518-f51d-336e-8e52-22cef763f4fd
# 7   27  0e2d9c07-3a39-3379-9ab9-8f2510dd09cb
# 8   28  fe0d4d22-4eae-35e8-ba3d-980202c0bb5b
# 9   29  79c2ee48-d1da-3e95-b5b2-380ced454999
# 10  30  6d02563b-2f04-3745-b91d-180130074230
# 11  31  8f1c648a-7c50-3821-a821-084a9b410c5a
# 12  32  81894c1b-0291-3817-b8f0-18a42936e0d9
# 13  33  0113fbd9-6c49-3afc-8b14-19b1588ad7f6
# 14  34  470533bb-ebd1-305b-8c1d-5fe1a62ab340
# 15  35  93e0e7cc-b420-331c-92d3-7f53819806fe
# 16  36  9ca73874-a884-3c68-85ed-3976ccb2fd90
# 17  37  2b2897c4-d520-3439-a542-7c53190f0a7b
# 18  38  7967ead0-d491-3288-8d41-94c2d4e20a1a
# 19  39  2e747676-d4c1-37b4-bcb0-da3a23efaf1c
# 20  40  fdb58aae-b272-3d41-9f77-ff73a20b9819
# 21  41  6cc00cda-d837-3d97-b78b-1e32878079ba
# 22  42  1fc3e8aa-b9c7-3806-841a-6228e6e3cf66
# 23  43  222a82b5-1230-3379-84e1-103af83837aa
# 24  44  62c44af4-454e-326b-953f-11db2f3f7b29
# 25  45  5e36cff0-34d6-3133-affc-7c19c9fe61cf
# 26  47  cb301294-5362-30e1-950b-128b6d019094
#
#                                                  text  documentId unlinked  \
# 0   Surprised that Tibshirani not here and referen...          33    false
# 1                                  ISBN 0-387-95457-0         170    false
# 2                               R package version 0.6         178    false
# 3                                {ISBN} 3-900051-07-0         140    false
# 4                               R package version 1.0         109    false
# 5            Has a small section on Bayesian Networks         156    false
# 6          The supplement gives preprocessing details         132    false
# 7    Prodigeous article on importance of interactions         296    false
# 8   Great review of ML methods used in GWAS with c...         294    false
# 9   Some poor english but looks like a reasonable ...         282    false
# 10                                proprietary article         275    false
# 11               Use this to detect the moving bottle         260    false
# 12                        Handbook of Statistics 2013         244    false
# 13                      OCRopus link. Touches on HMMs         238    false
# 14                                       Best on HMMS         366    false
# 15  ====================================<br/>Summa...         334    false
# 16  ==================================<br/>Summary...         312    false
# 17  ======================================<br/>Sum...         365    false
# 18  Comments on the splitting of images into secti...         357    false
# 19  proprietary article: Design and Implementation...         310    false
# 20  Summary:<br/>- Shows methods for binarising co...         333    false
# 21                Just links to Tesseract and OCRopus         367    false
# 22  Provides some tricks to improve location of fi...         376    false
# 23  Methods seem rudimentary. Only just now encorp...         392    false
# 24  Demo http://www.cs.toronto.edu/~graves/handwri...         358    false
# 25  <b>From Duplicate 1 (<i>Towards Reverse Engine...         316    false
# 26                                  here's a wee note         516    false
#
#                                              baseNote
# 0   Surprised that Tibshirani not here and referen...
# 1                                  ISBN 0-387-95457-0
# 2                               R package version 0.6
# 3                                {ISBN} 3-900051-07-0
# 4                               R package version 1.0
# 5            Has a small section on Bayesian Networks
# 6          The supplement gives preprocessing details
# 7    Prodigeous article on importance of interactions
# 8   Great review of ML methods used in GWAS with c...
# 9   Some poor english but looks like a reasonable ...
# 10                                proprietary article
# 11               Use this to detect the moving bottle
# 12                        Handbook of Statistics 2013
# 13                      OCRopus link. Touches on HMMs
# 14                                       Best on HMMS
# 15  ====================================<br/>Summa...
# 16  ==================================<br/>Summary...
# 17  ======================================<br/>Sum...
# 18  Comments on the splitting of images into secti...
# 19  proprietary article: Design and Implementation...
# 20  Summary:<br/>- Shows methods for binarising co...
# 21                Just links to Tesseract and OCRopus
# 22  Provides some tricks to improve location of fi...
# 23  Methods seem rudimentary. Only just now encorp...
# 24  Demo http://www.cs.toronto.edu/~graves/handwri...
# 25  <b>From Duplicate 1 (<i>Towards Reverse Engine...
# 26                                  here's a wee note

# %%
table_name = 'FileNotes'
filenotes = pd.read_sql_query("SELECT * from {}".format(table_name), db)
filenotes
# Out:
#     id author                                  uuid  documentId  \
# 0   34         557b63f6-4200-440c-92c0-1f2f50336ac8         195
# 1   35         6f99d38b-5b9f-4b44-9126-475012fe1ca8         195
# 2   36         c1198989-2adc-4bd8-bc3a-3092edfe803c         195
# 3   37         c4282806-9fe1-4ba6-af64-8e4150d94720         195
# 4   38         e763a018-4f57-47df-aaea-d42faa397d99         195
# 5   39         f10342bd-dba3-4a71-867f-a69c42e15bd7         195
# 6   40         8d78214f-f86c-4c3c-a015-9e656fd3de7d          12
# 7   41         b2d4f36e-6938-4a8e-bae9-74116fd48ce8          12
# 8   42         f0e9cb88-2da2-4b0a-bac0-5783e33ae1c7          12
# 9   43         0bd0e04d-0549-41dc-ac36-34eddbf0b08f         143
# 10  44         11e4c982-0f87-4489-9818-305f786675f9         143
# 11  45         13402b5d-aa44-45e1-a11b-9a354fcc581d         143
# 12  46         20b1fe2d-e21f-475b-866b-5916ca65034d         143
# 13  47         49da8945-a41c-4825-87bf-d453ee0e66bb         143
# 14  48         53c1f83a-3e98-4f4e-97c3-ce688abf1d44         143
# 15  49         5c96bdbb-ce65-46ec-b790-d933b7954ef5         143
# 16  50         65e89717-804d-4be7-badd-b9aeaecd3e75         143
# 17  51         81949c01-44dc-480a-8817-03dd50a03c35         143
# 18  52         8961eada-09c6-4143-971c-2b6b68b76592         143
# 19  53         a660994a-e79b-46b3-b6f4-39dd55555050         143
# 20  54         a6ad6c6a-8fd7-441b-8262-0defdf9a8c31         143
# 21  55         c2e6da1e-d3d3-424d-bf06-8955350fdd46         143
# 22  56         cec10ff3-c8f1-4974-8076-9a86e63271bb         143
# 23  57         c05d188e-a4dd-4b71-80a9-8d3756a0b3c3          69
# 24  58         038e6cf2-ce88-41cc-b76a-b32de31c813f          41
# 25  59         5d1ca909-c8ff-43b7-831e-912b39fe6ea4          41
# 26  60         66a5100d-314c-4151-a166-5c12b0181851          41
# 27  61         ebee6a53-3dc0-49a6-9865-d1eaf3761dd6          41
# 28  62         f261eeb7-c4f8-4e07-a7c4-84557b015f22          41
# 29  63         f39decbf-0432-4cc8-a7f1-75c34763403e          41
# 30  64         1024c000-78cc-40af-989d-e0373b781064         294
#
#                                     fileHash  page        x        y  \
# 0   4392f8295b579472827f884d41e83f008e587829   508  453.538  250.172
# 1   4392f8295b579472827f884d41e83f008e587829   498  453.538  284.794
# 2   4392f8295b579472827f884d41e83f008e587829   503  453.538  111.228
# 3   4392f8295b579472827f884d41e83f008e587829   512  453.538  322.236
# 4   4392f8295b579472827f884d41e83f008e587829   506  453.538  201.993
# 5   4392f8295b579472827f884d41e83f008e587829   500  453.538  346.777
# 6   8d58a4acfdf188b58166e327e764ffa3af472c54   155  471.751  335.274
# 7   8d58a4acfdf188b58166e327e764ffa3af472c54   132  266.062  473.169
# 8   8d58a4acfdf188b58166e327e764ffa3af472c54   135  259.996   65.430
# 9   9952983c9ddb9469bce8e0b3d361277ceb9fa90a     4  553.535  697.271
# 10  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     4  296.660  510.809
# 11  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  553.535  642.712
# 12  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  395.107  472.549
# 13  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     5  537.888  675.327
# 14  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     5  574.398  228.078
# 15  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  361.205  416.480
# 16  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  194.301  484.284
# 17  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     1  281.013  320.418
# 18  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     3  537.888  423.874
# 19  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     5  537.888  423.016
# 20  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  553.535  106.796
# 21  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  553.535  467.333
# 22  9952983c9ddb9469bce8e0b3d361277ceb9fa90a     2  553.535  467.333
# 23  201b835c3f3a3626ca07be68cc28cf7d286bf8d5    28  396.216  202.745
# 24  a0a776e73cde87038f4140b56a71553c66405bd6   273  456.528  618.064
# 25  a0a776e73cde87038f4140b56a71553c66405bd6   241  456.823  522.411
# 26  a0a776e73cde87038f4140b56a71553c66405bd6   241  456.823  422.441
# 27  a0a776e73cde87038f4140b56a71553c66405bd6   241  456.823  303.348
# 28  a0a776e73cde87038f4140b56a71553c66405bd6   263  456.528  386.258
# 29  a0a776e73cde87038f4140b56a71553c66405bd6   242  422.500  482.452
# 30  98ae0edc869990aa808fc852f9d1130ae0f6d86e     1  297.461  282.681
#
#                                                  note          modifiedTime  \
# 0   vote cast in proportion to predictive power......  2014-09-16T17:23:05Z
# 1   Traditional GWAS asssumes phenotypes affected ...  2014-09-16T17:23:05Z
# 2   Monte Carlo methods for feature selection in s...  2014-09-16T17:23:05Z
# 3               No single method will prevail as best  2014-09-16T17:23:06Z
# 4   Rndom forest show joint predictive power of an...  2014-09-16T17:23:05Z
# 5            Disadvantage of traditional GWAS methods  2014-09-16T17:23:05Z
# 6                              Gatsby assignment 1 q1  2014-10-11T23:38:07Z
# 7                                 Gatsby assignment 1  2014-10-11T23:38:07Z
# 8                                          question 2  2014-10-13T16:04:20Z
# 9   much lower accuracy on the small validation......  2014-09-16T17:23:05Z
# 10  Frigging Validation set by making proportional...  2014-09-16T17:23:05Z
# 11  http://en.wikipedia.org/wiki/International_Hap...  2014-09-16T17:23:05Z
# 12  Hardy-Weinberg can be controvertial\n\nFrom GW...  2014-09-16T17:23:05Z
# 13  Agreed, but since this method uses single sele...  2014-09-16T17:23:05Z
# 14  I really think this is unjustified since the s...  2014-09-16T17:23:06Z
# 15  Eigentrat method for extracting principal comp...  2014-09-16T17:23:05Z
# 16                                     V small sample  2014-09-16T17:23:06Z
# 17                      Seems ludicrously accurate...  2014-09-16T17:23:05Z
# 18  If you perform feature selection on all of the...  2014-09-16T17:23:04Z
# 19  Look up "multiple comparisons problem" and how...  2014-09-16T17:23:05Z
# 20  Surely this would throw away important interac...  2014-09-16T17:23:06Z
# 21  Missing data threshold quite high. Missing dat...  2014-09-16T17:23:05Z
# 22                                                     2014-09-16T17:23:06Z
# 23  Prove this (estimating binomial coefficients u...  2014-08-19T08:31:15Z
# 24  Try to understand why C.V. underestimates for ...  2014-09-16T17:23:06Z
# 25           Goals for Model Assessment and Selection  2014-09-16T17:23:06Z
# 26  Surprised that they advocate use of repeated v...  2014-09-16T17:23:05Z
# 27  [GOOD QUOTE] number of observations for each p...  2014-09-16T17:23:05Z
# 28                   Method for model choice using CV  2014-09-16T17:23:06Z
# 29  derived here http://artofsoftware.org/2012/09/...  2014-09-16T17:23:06Z
# 30  SNV analysis, finding rare variants, finds bet...  2014-10-10T22:32:11Z
#
#              createdTime unlinked  \
# 0   2014-09-16T17:23:05Z    false
# 1   2014-09-16T17:23:05Z    false
# 2   2014-09-16T17:23:05Z    false
# 3   2014-09-16T17:23:06Z    false
# 4   2014-09-16T17:23:05Z    false
# 5   2014-09-16T17:23:05Z    false
# 6   2014-10-11T23:38:07Z    false
# 7   2014-10-11T23:38:07Z    false
# 8   2014-10-13T16:04:20Z    false
# 9   2014-09-16T17:23:05Z    false
# 10  2014-09-16T17:23:05Z    false
# 11  2014-09-16T17:23:05Z    false
# 12  2014-09-16T17:23:05Z    false
# 13  2014-09-16T17:23:05Z    false
# 14  2014-09-16T17:23:06Z    false
# 15  2014-09-16T17:23:05Z    false
# 16  2014-09-16T17:23:06Z    false
# 17  2014-09-16T17:23:05Z    false
# 18  2014-09-16T17:23:04Z    false
# 19  2014-09-16T17:23:05Z    false
# 20  2014-09-16T17:23:06Z    false
# 21  2014-09-16T17:23:05Z    false
# 22  2014-09-16T17:23:06Z    false
# 23  2014-08-19T08:31:15Z    false
# 24  2014-09-16T17:23:06Z    false
# 25  2014-09-16T17:23:06Z    false
# 26  2014-09-16T17:23:05Z    false
# 27  2014-09-16T17:23:05Z    false
# 28  2014-09-16T17:23:06Z    false
# 29  2014-09-16T17:23:06Z    false
# 30  2014-10-10T22:32:11Z    false
#
#                                              baseNote    color  \
# 0   vote cast in proportion to predictive power......  #fff5ad
# 1   Traditional GWAS asssumes phenotypes affected ...  #fff5ad
# 2   Monte Carlo methods for feature selection in s...  #fff5ad
# 3               No single method will prevail as best  #fff5ad
# 4   Rndom forest show joint predictive power of an...  #fff5ad
# 5            Disadvantage of traditional GWAS methods  #fff5ad
# 6                              Gatsby assignment 1 q1  #fff5ad
# 7                                 Gatsby assignment 1  #fff5ad
# 8                                          question 2  #fff5ad
# 9   much lower accuracy on the small validation......  #fff5ad
# 10  Frigging Validation set by making proportional...  #fff5ad
# 11  http://en.wikipedia.org/wiki/International_Hap...  #fff5ad
# 12  Hardy-Weinberg can be controvertial\n\nFrom GW...  #fff5ad
# 13  Agreed, but since this method uses single sele...  #fff5ad
# 14  I really think this is unjustified since the s...  #fff5ad
# 15  Eigentrat method for extracting principal comp...  #fff5ad
# 16                                     V small sample  #fff5ad
# 17                      Seems ludicrously accurate...  #fff5ad
# 18  If you perform feature selection on all of the...  #fff5ad
# 19  Look up "multiple comparisons problem" and how...  #fff5ad
# 20  Surely this would throw away important interac...  #fff5ad
# 21  Missing data threshold quite high. Missing dat...  #fff5ad
# 22                                                     #fff5ad
# 23  Prove this (estimating binomial coefficients u...  #fff5ad
# 24  Try to understand why C.V. underestimates for ...  #fff5ad
# 25           Goals for Model Assessment and Selection  #fff5ad
# 26  Surprised that they advocate use of repeated v...  #fff5ad
# 27  [GOOD QUOTE] number of observations for each p...  #fff5ad
# 28                   Method for model choice using CV  #fff5ad
# 29  derived here http://artofsoftware.org/2012/09/...  #fff5ad
# 30  SNV analysis, finding rare variants, finds bet...  #fff5ad
#
#                              profileUuid
# 0   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 1   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 2   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 3   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 4   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 5   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 6   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 7   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 8   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 9   5fa04bd3-0920-34d8-8244-b307ceccd21d
# 10  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 11  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 12  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 13  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 14  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 15  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 16  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 17  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 18  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 19  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 20  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 21  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 22  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 23  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 24  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 25  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 26  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 27  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 28  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 29  5fa04bd3-0920-34d8-8244-b307ceccd21d
# 30  5fa04bd3-0920-34d8-8244-b307ceccd21d

# %%
table_name = 'Folders'
folders = pd.read_sql_query("SELECT * from {}".format(table_name), db)
folders
# Out:
#    id  uuid         name  parentId         access    syncPolicy  \
# 0   1  None  MusicDecomp        -1  PrivateAccess  SyncAllFiles
# 1   2  None         IRDS        -1  PrivateAccess  SyncAllFiles
#
#   downloadFilesPolicy uploadFilesPolicy publicUrl description creatorName  \
# 0                true              true
# 1                true              true
#
#   creatorProfileUrl
# 0
# 1

# %%
table_name = 'DocumentFolders'
docfolders = pd.read_sql_query("SELECT * from {}".format(table_name), db)
docfolders
# Out:
#      documentId  folderId           status
# 0           408         2  ObjectUnchanged
# 1           411         2  ObjectUnchanged
# 2           429         2  ObjectUnchanged
# 3           413         2  ObjectUnchanged
# 4           434         2  ObjectUnchanged
# 5           441         2  ObjectUnchanged
# 6           407         1  ObjectUnchanged
# 7           410         1  ObjectUnchanged
# 8           412         1  ObjectUnchanged
# 9           414         1  ObjectUnchanged
# 10          415         1  ObjectUnchanged
# 11          416         1  ObjectUnchanged
# 12          417         1  ObjectUnchanged
# 13          418         1  ObjectUnchanged
# 14          419         1  ObjectUnchanged
# 15          420         1  ObjectUnchanged
# 16          421         1  ObjectUnchanged
# 17          422         1  ObjectUnchanged
# 18          423         1  ObjectUnchanged
# 19          424         1  ObjectUnchanged
# 20          425         1  ObjectUnchanged
# 21          426         1  ObjectUnchanged
# 22          428         1  ObjectUnchanged
# 23          431         1  ObjectUnchanged
# 24          432         1  ObjectUnchanged
# 25          433         1  ObjectUnchanged
# 26          436         1  ObjectUnchanged
# 27          437         1  ObjectUnchanged
# 28          402         1  ObjectUnchanged
# 29          405         1  ObjectUnchanged
# ..          ...       ...              ...
# 83          565         1  ObjectUnchanged
# 84          566         1  ObjectUnchanged
# 85          567         1  ObjectUnchanged
# 86          568         1  ObjectUnchanged
# 87          569         1  ObjectUnchanged
# 88          570         1  ObjectUnchanged
# 89          571         1  ObjectUnchanged
# 90          572         1  ObjectUnchanged
# 91          573         1  ObjectUnchanged
# 92          574         1  ObjectUnchanged
# 93          575         1  ObjectUnchanged
# 94          576         1  ObjectUnchanged
# 95          577         1  ObjectUnchanged
# 96          579         1  ObjectUnchanged
# 97          580         1  ObjectUnchanged
# 98          583         1  ObjectUnchanged
# 99          584         1  ObjectUnchanged
# 100         585         1  ObjectUnchanged
# 101         587         1  ObjectUnchanged
# 102         586         1  ObjectUnchanged
# 103         588         1  ObjectUnchanged
# 104         589         1  ObjectUnchanged
# 105         590         1  ObjectUnchanged
# 106         591         1  ObjectUnchanged
# 107         592         1  ObjectUnchanged
# 108         593         1  ObjectUnchanged
# 109         594         1  ObjectUnchanged
# 110         595         1  ObjectUnchanged
# 111         596         1  ObjectUnchanged
# 112         602         1  ObjectUnchanged
#
# [113 rows x 3 columns]
